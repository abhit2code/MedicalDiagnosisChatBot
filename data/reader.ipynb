# %%
import pickle

# %%
with open('train.pk','rb') as f:
    train_data = pickle.load(f)

# %%
print(type(train_data), len(train_data))
# Out:
# <class 'list'> 1912

# %%
train_data
# Out:
# [{'explicit_inform_slots': {'Cough': True,
#    'Chest tightness and shortness of breath': False},
#   'implicit_inform_slots': {'Pain behind the breastbone': False,
#    'Chest tightness': False,
#    'Hemoptysis': True,
#    'Expectoration': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Acid reflux': True,
#    'Chest tightness': False},
#   'implicit_inform_slots': {'Pain behind the breastbone': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Cough': True, 'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Vomiting': True,
#    'Diarrhea': True,
#    'Nausea': True,
#    'Bloating': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccough': True,
#    'Acid reflux': True,
#    'Bloating': False},
#   'implicit_inform_slots': {'Stomach ache': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Pain behind the breastbone': True},
#   'implicit_inform_slots': {'Stomach ache': False, 'Hiccough': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True, 'Chest tightness': True},
#   'implicit_inform_slots': {'Stomach ache': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Stomach ache': True, 'Bloating': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Shortness of breath': True, 'Hiccup': True},
#   'implicit_inform_slots': {'Pharynx discomfort': False,
#    'Cough': True,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Fatigue': True,
#    'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Chest tightness': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Cough': True,
#    'Stomach ache': False,
#    'Nausea': False,
#    'Diarrhea': False,
#    'Sweating': False},
#   'implicit_inform_slots': {'Chest tightness and shortness of breath': False,
#    'Pain behind the breastbone': False,
#    'Vomiting': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Expectoration': True, 'Cough': True},
#   'implicit_inform_slots': {'Fever': False, 'Stomach ache': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Vomiting': True,
#    'Stomach ache': False,
#    'Diarrhea': False,
#    'Consciousness disorder': False,
#    'Twitch': False},
#   'implicit_inform_slots': {'Pain behind the breastbone': False,
#    'Chest tightness': False,
#    'Acid reflux': True,
#    'Pharynx discomfort': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccough': True, 'Stomach ache': False},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Nausea': False,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Stomach ache': True, 'Hiccough': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccough': True, 'Vomiting': False},
#   'implicit_inform_slots': {'Burning sensation behind the breastbone': False,
#    'Acid reflux': False,
#    'Hard to swallow': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Vomiting': True},
#   'implicit_inform_slots': {'Stomach ache': True, 'Nausea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bitter': True,
#    'Stomach ache': False,
#    'Vomiting': False,
#    'Bloating': False},
#   'implicit_inform_slots': {'Acid reflux': False,
#    'Nausea': False,
#    'Thirst': True,
#    'Hiccup': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Hiccup': False,
#    'Expectoration': False},
#   'implicit_inform_slots': {'Cough': False,
#    'Stomach ache': False,
#    'Chest tightness': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Nausea': True},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Diarrhea': False,
#    'Vomiting': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Vomiting': True,
#    'Cough': False,
#    'Stomach ache': False,
#    'Pain behind the breastbone': False,
#    'Nausea': False,
#    'Sweating': False},
#   'implicit_inform_slots': {'Chest tightness and shortness of breath': False,
#    'Diarrhea': False,
#    'Chest tightness': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Stomach ache': True,
#    'Poor sleep': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Hiccup': True,
#    'Stomach ache': False,
#    'Vomiting': False,
#    'Nausea': False},
#   'implicit_inform_slots': {'Bloating': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pain behind the breastbone': True,
#    'Diarrhea': False},
#   'implicit_inform_slots': {'Acid reflux': False,
#    'Vomiting': False,
#    'Hiccup': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Cough': True, 'Stomach ache': False},
#   'implicit_inform_slots': {'Hemoptysis': False,
#    'Pharynx discomfort': False,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bloating': True,
#    'Acid reflux': True,
#    'Stomach ache': False},
#   'implicit_inform_slots': {'Vomiting': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pain behind the breastbone': True,
#    'Nausea': True,
#    'Stomach ache': False},
#   'implicit_inform_slots': {'Thin': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Burning sensation behind the breastbone': True,
#    'Vomiting': False},
#   'implicit_inform_slots': {'Diarrhea': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Burning sensation behind the breastbone': True,
#    'Nausea': False},
#   'implicit_inform_slots': {'Vomiting': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bitter': True},
#   'implicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Acid reflux': True,
#    'Palpitations': True,
#    'Poor sleep': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Hiccough': True,
#    'Chest tightness': False,
#    'Cough': False,
#    'Chest tightness and shortness of breath': False,
#    'Diarrhea': False,
#    'Nausea': False,
#    'Sweating': False},
#   'implicit_inform_slots': {'Stomach ache': False, 'Vomiting': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pain behind the breastbone': True,
#    'Acid reflux': True},
#   'implicit_inform_slots': {'Stomach ache': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Stomach ache': True, 'Acid reflux': True},
#   'implicit_inform_slots': {'Hiccup': True, 'Bloating': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Chest tightness': True,
#    'Chest tightness and shortness of breath': True,
#    'Cough': False,
#    'Black stool': False,
#    'Fever': False,
#    'Palpitations': False,
#    'Vomiting': False},
#   'implicit_inform_slots': {'Diarrhea': False, 'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccough': True,
#    'Burning sensation behind the breastbone': True,
#    'Thin': False,
#    'Diarrhea': False},
#   'implicit_inform_slots': {'Vomiting': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Bitter': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Bloating': True,
#    'Nausea': False},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Burning sensation behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Stomach ache': False, 'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Sleep disorder': True},
#   'implicit_inform_slots': {'Poor sleep': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Headache': False,
#    'Consciousness disorder': False,
#    'Fever': False,
#    'Dizziness': False},
#   'implicit_inform_slots': {'Twitch': False,
#    'Pain behind the breastbone': False,
#    'Vomiting': True,
#    'Feel sick and vomit': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccup': True,
#    'Pain behind the breastbone': True,
#    'Stomach ache': False,
#    'Burning sensation behind the breastbone': False,
#    'Acid reflux': False},
#   'implicit_inform_slots': {'Diarrhea': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccough': True},
#   'implicit_inform_slots': {'Stomach ache': True,
#    'Hard to swallow': True,
#    'Pain behind the breastbone': True,
#    'Nausea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bloating': True, 'Hematemesis': False},
#   'implicit_inform_slots': {'Chest tightness and shortness of breath': False,
#    'Chest tightness': False,
#    'Stomach ache': True,
#    'Feel sick and vomit': True,
#    'Nausea': True,
#    'Dizziness': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Stomach ache': True, 'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Nausea': True,
#    'Acid reflux': False,
#    'Diarrhea': False,
#    'Fever': False,
#    'Black stool': False},
#   'implicit_inform_slots': {'Fear of cold': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccup': True, 'Acid reflux': True},
#   'implicit_inform_slots': {'Pharynx discomfort': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccup': True},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Pain behind the breastbone': True,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Burning sensation behind the breastbone': True,
#    'Hard to swallow': False,
#    'Fever': False,
#    'Bloating': False,
#    'Stomach ache': False,
#    'Pharynx discomfort': False,
#    'Fear of cold': False},
#   'implicit_inform_slots': {'Feel sick and vomit': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Nausea': True,
#    'Stomach ache': False,
#    'Bloating': False},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Burning sensation behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Chest tightness': True,
#    'Nausea': True,
#    'Cough': False,
#    'Chest tightness and shortness of breath': False,
#    'Diarrhea': False,
#    'Stomach ache': False,
#    'Pain behind the breastbone': False,
#    'Vomiting': False},
#   'implicit_inform_slots': {'Sweating': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccup': True},
#   'implicit_inform_slots': {'Hard to swallow': False,
#    'Vomiting': False,
#    'Burning sensation behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hard to swallow': True, 'Acid reflux': True},
#   'implicit_inform_slots': {'Burning sensation behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Chest tightness': True,
#    'Chest tightness and shortness of breath': False,
#    'Diarrhea': False,
#    'Stomach ache': False,
#    'Pain behind the breastbone': False,
#    'Vomiting': False,
#    'Nausea': False,
#    'Sweating': False},
#   'implicit_inform_slots': {'Cough': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hard to swallow': True, 'Nausea': True},
#   'implicit_inform_slots': {'Acid reflux': True, 'Pharynx discomfort': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Stomach ache': True,
#    'Diarrhea': False,
#    'Vomiting': False,
#    'Runny nose': False,
#    'Constipation': False,
#    'Twitch': False},
#   'implicit_inform_slots': {'Fever': False, 'Cough': False, 'Nausea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Dizzy': True,
#    'Chest tightness': True,
#    'Stomach ache': False,
#    'Pain behind the breastbone': False,
#    'Bloating': False},
#   'implicit_inform_slots': {'Syncope': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Nausea': True, 'Acid reflux': True},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Burning sensation behind the breastbone': True,
#    'Stomach ache': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Vomiting': True,
#    'Stomach ache': False,
#    'Pain behind the breastbone': False,
#    'Nausea': False},
#   'implicit_inform_slots': {'Hematemesis': False,
#    'Black stool': False,
#    'Hard to swallow': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Fear of cold': False,
#    'Stomach ache': False,
#    'Vomiting': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Bloating': False,
#    'Nausea': False,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hard to swallow': True,
#    'Palpitations': True,
#    'Stomach ache': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Cough': False,
#    'Pain behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Chest tightness and shortness of breath': False,
#    'Black stool': False,
#    'Stomach ache': False,
#    'Hematemesis': False,
#    'Pain behind the breastbone': False},
#   'implicit_inform_slots': {'Chest tightness': False,
#    'Bloating': False,
#    'Thin white moss': True,
#    'Feel sick and vomit': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Stomach ache': False,
#    'Diarrhea': False,
#    'Fever': False,
#    'Constipation': False},
#   'implicit_inform_slots': {'Feel sick and vomit': False,
#    'Black stool': False,
#    'Burning sensation behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Nausea': False},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Bloating': False,
#    'Stomach ache': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hard to swallow': True, 'Stomach ache': False},
#   'implicit_inform_slots': {'Cough': False,
#    'Fever': False,
#    'Chest tightness': True,
#    'Pain behind the breastbone': True,
#    'Poor spirits': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Edema': True},
#   'implicit_inform_slots': {'Diplopia': False,
#    'Fever': False,
#    'Pharynx discomfort': True,
#    'Runny nose': True,
#    'Stuffy nose': True,
#    'Blood in the tears': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Chest tightness': True, 'Cough': False},
#   'implicit_inform_slots': {'Bloating': False,
#    'Acid reflux': False,
#    'Stomach ache': True,
#    'Hiccup': True,
#    'Pharynx discomfort': True,
#    'Shortness of breath': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Constipation': True},
#   'implicit_inform_slots': {'Hard to swallow': False, 'Stomach ache': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pain behind the breastbone': True},
#   'implicit_inform_slots': {'Shortness of breath': False,
#    'Chest tightness': True,
#    'Cough': True,
#    'Chest tightness and shortness of breath': True,
#    'Palpitations': True,
#    'Pharynx discomfort': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bloating': True, 'Thin': False},
#   'implicit_inform_slots': {'Diarrhea': False,
#    'Anorexia': False,
#    'Burning sensation behind the breastbone': True,
#    'Acid reflux': True,
#    'Bitter': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Stomach ache': True,
#    'Increased stool frequency': True,
#    'Chest tightness and shortness of breath': False},
#   'implicit_inform_slots': {'Chest tightness': False, 'Nausea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Feel sick and vomit': False,
#    'Stomach ache': False,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bloating': True,
#    'Hiccough': True,
#    'Vomiting': False,
#    'Diarrhea': False,
#    'Nausea': False},
#   'implicit_inform_slots': {'Stomach ache': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Feel sick and vomit': True,
#    'Hard to swallow': True,
#    'Chest tightness': False,
#    'Stomach ache': False,
#    'Hoarse': False},
#   'implicit_inform_slots': {'Pain behind the breastbone': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Chest tightness': True,
#    'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Acid reflux': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Bloating': False,
#    'Cough': True,
#    'Pharynx discomfort': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Stuffy nose': False,
#    'Cough': False,
#    'Fever': False,
#    'Acid reflux': False,
#    'Vomiting': False,
#    'Runny nose': False},
#   'implicit_inform_slots': {'Expectoration': False,
#    'Nausea': False,
#    'Chest tightness': True,
#    'Difficulty breathing': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True, 'Bloating': False},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Stomach ache': False,
#    'Burning sensation behind the breastbone': True,
#    'Dizziness': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hard to swallow': True,
#    'Nausea': True,
#    'Stomach ache': False,
#    'Vomiting': False},
#   'implicit_inform_slots': {'Bloating': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Chest tightness': False,
#    'Hard to swallow': True,
#    'Pain behind the breastbone': True,
#    'Nausea': True,
#    'Vomiting': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Nausea': True,
#    'Hard to swallow': False,
#    'Palpitations': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Hoarse': False, 'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Diarrhea': True},
#   'implicit_inform_slots': {'Burning sensation behind the breastbone': False,
#    'Pain behind the breastbone': False,
#    'Vomiting': True,
#    'Acid reflux': True,
#    'Feel sick and vomit': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Stuffy nose': True,
#    'Palpitations': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Hard to swallow': False,
#    'Hoarse': False,
#    'Pharynx discomfort': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True, 'Nausea': False},
#   'implicit_inform_slots': {'Fever': False,
#    'Vomiting': False,
#    'Burning sensation behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True, 'Body aches': False},
#   'implicit_inform_slots': {'Pain behind the breastbone': False,
#    'Fever': False,
#    'Stuffy nose': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Increased stool frequency': True,
#    'Vomiting': False},
#   'implicit_inform_slots': {'Nausea': False,
#    'Burning sensation behind the breastbone': False,
#    'Acid reflux': True,
#    'Bloating': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bloating': True},
#   'implicit_inform_slots': {'Black stool': False,
#    'Stomach ache': False,
#    'Hiccough': True,
#    'Acid reflux': True,
#    'Nausea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Nausea': True},
#   'implicit_inform_slots': {'Pain behind the breastbone': True,
#    'Pharynx discomfort': True,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccough': True,
#    'Chest tightness and shortness of breath': False,
#    'Diarrhea': False,
#    'Stomach ache': False,
#    'Nausea': False,
#    'Sweating': False},
#   'implicit_inform_slots': {'Pain behind the breastbone': False,
#    'Cough': False,
#    'Chest tightness': True,
#    'Vomiting': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Stomach ache': False,
#    'Nausea': False},
#   'implicit_inform_slots': {'Thin': False,
#    'Vomiting': False,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Hiccup': True,
#    'Chest tightness': False,
#    'Pain behind the breastbone': False},
#   'implicit_inform_slots': {'Stomach ache': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Cough': True,
#    'Chest tightness and shortness of breath': True,
#    'Palpitations': False},
#   'implicit_inform_slots': {'Edema': False,
#    'Chest tightness': True,
#    'Pain behind the breastbone': True,
#    'Expectoration': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pain behind the breastbone': True,
#    'Hard to swallow': True,
#    'Stomach ache': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Cough': False, 'Chest tightness': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Hiccough': True, 'Pharynx discomfort': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True, 'Stomach ache': False},
#   'implicit_inform_slots': {'Burning sensation behind the breastbone': False,
#    'Bloating': False,
#    'Nausea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Cough': True, 'Fever': False},
#   'implicit_inform_slots': {'Expectoration': False,
#    'Chest tightness and shortness of breath': False,
#    'Pain behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Stomach ache': False, 'Hiccough': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bloating': True,
#    'Stomach ache': False,
#    'Pain behind the breastbone': False,
#    'Nausea': False},
#   'implicit_inform_slots': {'Chest tightness': False,
#    'Vomiting': False,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True, 'Black stool': False},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Nausea': False,
#    'Burning sensation behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Bloating': True,
#    'Fever': False,
#    'Nausea': False,
#    'Black stool': False},
#   'implicit_inform_slots': {'Vomiting': False, 'Stomach ache': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Hoarse': True,
#    'Cough': False,
#    'Vomiting': False,
#    'Nausea': False,
#    'Expectoration': False},
#   'implicit_inform_slots': {'Pharynx discomfort': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bloating': True, 'Diarrhea': False},
#   'implicit_inform_slots': {'Hard to swallow': False,
#    'Vomiting': False,
#    'Acid reflux': True,
#    'Nausea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Acid reflux': False, 'Bloating': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Burning sensation behind the breastbone': True,
#    'Vomiting': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Nausea': False, 'Thirst': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pain behind the breastbone': True},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Acid reflux': True,
#    'Nausea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Thin white moss': True,
#    'Stomach ache': True,
#    'Hard to swallow': False,
#    'Diarrhea': False,
#    'Fever': False,
#    'Vomiting': False,
#    'Fear of cold': False},
#   'implicit_inform_slots': {'Acid reflux': False, 'Nausea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Hiccough': True,
#    'Expectoration': False,
#    'Cough': False,
#    'Fever': False,
#    'Palpitations': False,
#    'Sweating': False},
#   'implicit_inform_slots': {'Chest tightness': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Stomach ache': True,
#    'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Cough': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccough': True},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Burning sensation behind the breastbone': True,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Stomach ache': True,
#    'Bloating': True,
#    'Chest tightness and shortness of breath': False,
#    'Palpitations': False,
#    'Acid reflux': False},
#   'implicit_inform_slots': {'Black stool': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Cough': True,
#    'Expectoration': False,
#    'Diarrhea': False,
#    'Fever': False,
#    'Stomach ache': False,
#    'Nausea': False},
#   'implicit_inform_slots': {'Vomiting': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Cough': True,
#    'Pharynx discomfort': True,
#    'Palpitations': False,
#    'Expectoration': False},
#   'implicit_inform_slots': {'Shortness of breath': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Expectoration': True,
#    'Pain behind the breastbone': True,
#    'Fever': False},
#   'implicit_inform_slots': {'Headache': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True},
#   'implicit_inform_slots': {'Pain behind the breastbone': True,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Acid reflux': True,
#    'Stomach ache': False,
#    'Vomiting': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Nausea': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hard to swallow': True,
#    'Pharynx discomfort': True},
#   'implicit_inform_slots': {'Acid reflux': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Stomach ache': True,
#    'Nausea': False},
#   'implicit_inform_slots': {'Vomiting': False, 'Bloating': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Chest tightness and shortness of breath': True,
#    'Pain behind the breastbone': True,
#    'Vomiting': False,
#    'Nausea': False},
#   'implicit_inform_slots': {'Acid reflux': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pain behind the breastbone': True,
#    'Nausea': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Diarrhea': False,
#    'Loss of appetite': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Dizziness': True},
#   'implicit_inform_slots': {'Chest tightness and shortness of breath': False,
#    'Chest tightness': True,
#    'Burning sensation behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccup': True,
#    'Bloating': True,
#    'Vomiting': False,
#    'Acid reflux': False,
#    'Nausea': False,
#    'Black stool': False},
#   'implicit_inform_slots': {'Burning sensation behind the breastbone': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pain behind the breastbone': True,
#    'Fever': False},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Cough': False,
#    'Chest tightness': True,
#    'Hard to swallow': True,
#    'Nausea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccup': True,
#    'Chest tightness': False,
#    'Headache': False,
#    'Stomach ache': False,
#    'Acid reflux': False},
#   'implicit_inform_slots': {'Dizziness': False,
#    'Consciousness disorder': False,
#    'Pain behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Vomiting': True,
#    'Hiccough': False,
#    'Chest tightness and shortness of breath': False,
#    'Diarrhea': False,
#    'Stomach ache': False,
#    'Acid reflux': False,
#    'Nausea': False,
#    'Sweating': False},
#   'implicit_inform_slots': {'Cough': False,
#    'Pain behind the breastbone': False,
#    'Chest tightness': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Nausea': False, 'Hiccough': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Bitter': True,
#    'Bloating': False},
#   'implicit_inform_slots': {'Hard to swallow': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Burning sensation behind the breastbone': True,
#    'Stomach ache': False,
#    'Vomiting': False,
#    'Pain behind the breastbone': False,
#    'Nausea': False},
#   'implicit_inform_slots': {'Chest tightness': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True,
#    'Acid reflux': True,
#    'Stomach ache': False,
#    'Vomiting': False},
#   'implicit_inform_slots': {'Nausea': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Hard to swallow': False,
#    'Palpitations': False},
#   'implicit_inform_slots': {'Fever': False, 'Cough': False, 'Hoarse': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Cough': True,
#    'Chest tightness and shortness of breath': False,
#    'Diarrhea': False,
#    'Stomach ache': False,
#    'Pain behind the breastbone': False,
#    'Vomiting': False,
#    'Nausea': False},
#   'implicit_inform_slots': {'Sweating': False, 'Dizziness': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Vomiting': False,
#    'Acid reflux': True,
#    'Nausea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Stomach ache': True,
#    'Thin white moss': True,
#    'Vomiting': False},
#   'implicit_inform_slots': {'Nausea': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Nausea': True, 'Pharynx discomfort': True},
#   'implicit_inform_slots': {'Cough': False, 'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Cough': False,
#    'Stomach ache': False,
#    'Diarrhea': False},
#   'implicit_inform_slots': {'Hard to swallow': False,
#    'Vomiting': False,
#    'Nausea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bloating': True},
#   'implicit_inform_slots': {'Burning sensation behind the breastbone': False,
#    'Acid reflux': False,
#    'Diarrhea': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pain behind the breastbone': True,
#    'Expectoration': True,
#    'Stomach ache': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Sweating': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Acid reflux': False, 'Stomach ache': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hard to swallow': True,
#    'Poor spirits': True,
#    'Cough': False,
#    'Stomach ache': False,
#    'Fever': False,
#    'Pain behind the breastbone': False},
#   'implicit_inform_slots': {'Chest tightness': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Chest tightness': True,
#    'Limb numbness': False,
#    'Twitch': False},
#   'implicit_inform_slots': {'Fatigue': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccup': True,
#    'Acid reflux': True,
#    'Cough': False},
#   'implicit_inform_slots': {'Fever': False, 'Pharynx discomfort': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Nausea': True,
#    'Acid reflux': True,
#    'Vomiting': False,
#    'Bloating': False},
#   'implicit_inform_slots': {'Stomach ache': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Stomach ache': False,
#    'Nausea': False,
#    'Fear of cold': False,
#    'Bloating': False},
#   'implicit_inform_slots': {'Fever': False, 'Vomiting': False, 'Bitter': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bloating': True,
#    'Pain behind the breastbone': True},
#   'implicit_inform_slots': {'Acid reflux': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Burning sensation behind the breastbone': True,
#    'Chest tightness': False,
#    'Headache': False,
#    'Chest tightness and shortness of breath': False,
#    'Diarrhea': False,
#    'Fever': False,
#    'Bloating': False,
#    'Stomach ache': False,
#    'Dizzy': False,
#    'Pain behind the breastbone': False,
#    'Palpitations': False,
#    'Nausea': False},
#   'implicit_inform_slots': {'Vomiting': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hiccup': True,
#    'Stomach ache': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Chest tightness': False,
#    'Palpitations': False,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hard to swallow': True, 'Hematemesis': False},
#   'implicit_inform_slots': {'Black stool': False,
#    'Pain behind the breastbone': False,
#    'Cough': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bloating': True},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Burning sensation behind the breastbone': True,
#    'Acid reflux': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Stomach ache': True,
#    'Acid reflux': True,
#    'Chest tightness': False},
#   'implicit_inform_slots': {'Pain behind the breastbone': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Cough': True, 'Hemoptysis': False},
#   'implicit_inform_slots': {'Chest tightness and shortness of breath': False,
#    'Fever': False,
#    'Expectoration': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Acid reflux': True,
#    'Frequent urination': True,
#    'Bloating': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Nausea': True,
#    'Hard to swallow': False},
#   'implicit_inform_slots': {'Vomiting': False, 'Pharynx discomfort': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Expectoration': True, 'Pharynx discomfort': True},
#   'implicit_inform_slots': {'Hard to swallow': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Burning sensation behind the breastbone': True,
#    'Anorexia': True,
#    'Bloating': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Hard to swallow': True,
#    'Chest tightness': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Cough': False,
#    'Pain behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Pain behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True, 'Acid reflux': True},
#   'implicit_inform_slots': {'Fever': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True,
#    'Burning sensation behind the breastbone': True},
#   'implicit_inform_slots': {'Pain behind the breastbone': False},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Nausea': False,
#    'Pain behind the breastbone': True},
#   'disease_tag': 'Esophagitis'},
#  {'explicit_inform_slots': {'Bloating': True},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Fever': False,
#    'Diarrhea': True,
#    'Nausea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Fever': True, 'Headache': True},
#   'implicit_inform_slots': {'Diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Defecate': True,
#    'Vomiting': True,
#    'Cough': False,
#    'Chest tightness and shortness of breath': False,
#    'Cyanosis': False},
#   'implicit_inform_slots': {'Fever': False},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Defecate': True},
#   'implicit_inform_slots': {'Fever': False, 'Stomach ache': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True,
#    'Abdominal pain and diarrhea': True,
#    'Fever': False},
#   'implicit_inform_slots': {'Vomiting': False, 'Stomach ache': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True, 'Fever': True},
#   'implicit_inform_slots': {'Stomach ache': False},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Vomiting': True,
#    'Fear of cold': True,
#    'Acid reflux': False,
#    'Diarrhea': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Stomach ache': False,
#    'Defecate': True,
#    'Nausea': True,
#    'Bloating': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Edema': True},
#   'implicit_inform_slots': {'Stomach ache': False, 'Diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Vomiting': True, 'Diarrhea': True},
#   'implicit_inform_slots': {'Stomach ache': False},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Defecate': True,
#    'Diarrhea': True,
#    'Mucus pus and blood in the stool': False,
#    'Fever': False,
#    'Black stool': False},
#   'implicit_inform_slots': {'Thirst': False},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Fatigue': True,
#    'Diarrhea': True,
#    'Nausea': False},
#   'implicit_inform_slots': {'Fever': False,
#    'Poor spirits': True,
#    'Stomach ache': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Loss of appetite': True},
#   'implicit_inform_slots': {'Cough': False,
#    'Vomiting': False,
#    'Stuffy nose': True,
#    'Diarrhea': True,
#    'Fever': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Vomiting': True},
#   'implicit_inform_slots': {'Fever': False,
#    'Stomach ache': False,
#    'Feel sick and vomit': True,
#    'Diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Loss of appetite': True, 'Nausea': False},
#   'implicit_inform_slots': {'Fever': False,
#    'Vomiting': False,
#    'Diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Loss of appetite': True},
#   'implicit_inform_slots': {'Fever': False, 'Cough': True, 'Runny nose': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Stomach ache': True},
#   'implicit_inform_slots': {'Fever': False,
#    'Feel sick and vomit': True,
#    'Diarrhea': True,
#    'Dizziness': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Defecate': True,
#    'Stomach ache': True,
#    'Fever': False},
#   'implicit_inform_slots': {'Chest tightness and shortness of breath': False},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True, 'Hematemesis': False},
#   'implicit_inform_slots': {'Black stool': False,
#    'Chills': False,
#    'Feel sick and vomit': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Stomach ache': True, 'Diarrhea': True},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Body aches': True,
#    'Fever': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Defecate': True},
#   'implicit_inform_slots': {'Stomach ache': True, 'Fever': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Bloating': True, 'Nausea': True},
#   'implicit_inform_slots': {'Diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Defecate': True,
#    'Diarrhea': True,
#    'Difficulty breathing': False},
#   'implicit_inform_slots': {'Fever': False, 'Pharynx discomfort': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Fever': True,
#    'Cough': False},
#   'implicit_inform_slots': {'Vomiting': False, 'Diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True,
#    'Abdominal pain and diarrhea': True},
#   'implicit_inform_slots': {'Fear of cold': False,
#    'Stomach ache': True,
#    'Vomiting': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Vomiting': True, 'Fever': False},
#   'implicit_inform_slots': {'Suppuration': False,
#    'Mucus pus and blood in the stool': False,
#    'Thirst': True,
#    'Diarrhea': True,
#    'Decreased urine output': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Cough': True},
#   'implicit_inform_slots': {'Sneeze': False,
#    'Runny nose': False,
#    'Bloody stools': True,
#    'Diarrhea': True,
#    'Fever': True,
#    'Loss of appetite': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Fever': False,
#    'Decreased urine output': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True,
#    'Anorexia': True,
#    'Rash': False,
#    'Chills': False},
#   'implicit_inform_slots': {'Twitch': False, 'Fever': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Fear of cold': True, 'Nausea': True},
#   'implicit_inform_slots': {'Stomach ache': True,
#    'Diarrhea': True,
#    'Fever': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Fever': True, 'Vomiting': True},
#   'implicit_inform_slots': {'Cough': False, 'Diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Headache': True,
#    'Chest tightness': False,
#    'Stuffy nose': False,
#    'Cough': False,
#    'Chest tightness and shortness of breath': False,
#    'Palpitations': False},
#   'implicit_inform_slots': {'Pharynx discomfort': False,
#    'Runny nose': False,
#    'Diarrhea': True,
#    'Nausea': True,
#    'Fever': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Vomiting': True,
#    'Diarrhea': True,
#    'Twitch': False,
#    'Chills': False},
#   'implicit_inform_slots': {'Mucus pus and blood in the stool': False,
#    'Fever': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True,
#    'Stomach ache': True,
#    'Fear of cold': False},
#   'implicit_inform_slots': {'Fever': False,
#    'Abdominal pain and diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True,
#    'Cough': True,
#    'Mucus pus and blood in the stool': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Vomiting': False, 'Decreased urine output': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True, 'Stomach ache': True},
#   'implicit_inform_slots': {'Vomiting': False},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Decreased urine output': True, 'Fever': False},
#   'implicit_inform_slots': {'Mucus pus and blood in the stool': False,
#    'Vomiting': False,
#    'Diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True},
#   'implicit_inform_slots': {'Stomach ache': True, 'Fever': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Bloating': True,
#    'Chest tightness': False,
#    'Headache': False,
#    'Diarrhea': False,
#    'Fever': False,
#    'Dizziness': False},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Pain behind the breastbone': False,
#    'Nausea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Suppuration': False,
#    'Fever': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Vomiting': True,
#    'Stuffy nose': True,
#    'Twitch': False,
#    'Runny nose': False,
#    'Fever': False,
#    'Rash': False},
#   'implicit_inform_slots': {'Cough': False},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Vomiting': True},
#   'implicit_inform_slots': {'Chills': False, 'Fever': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Palpitations': True,
#    'Stomach ache': True,
#    'Fever': False},
#   'implicit_inform_slots': {'Vomiting': False,
#    'Diarrhea': True,
#    'Nausea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Fear of cold': True},
#   'implicit_inform_slots': {'Vomiting': True, 'Diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Defecate': True, 'Stomach ache': True},
#   'implicit_inform_slots': {'Fever': False,
#    'Abdominal pain and diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True,
#    'Nausea': True,
#    'Mucus pus and blood in the stool': False},
#   'implicit_inform_slots': {'Vomiting': False, 'Stomach ache': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True, 'Vomiting': True},
#   'implicit_inform_slots': {'Fever': False, 'Pharynx discomfort': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Vomiting': True,
#    'Loss of appetite': True,
#    'Cough': False},
#   'implicit_inform_slots': {'Cry': False},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Decreased urine output': True,
#    'Vomiting': False,
#    'Twitch': False},
#   'implicit_inform_slots': {'Rash': False,
#    'Fever': False,
#    'Increased stool frequency': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True,
#    'Stomach ache': True,
#    'Thirst': False},
#   'implicit_inform_slots': {'Vomiting': False},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Stomach ache': True},
#   'implicit_inform_slots': {'Constipation': True, 'Bloating': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Runny nose': True},
#   'implicit_inform_slots': {'Cough': True, 'Diarrhea': True, 'Fever': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True},
#   'implicit_inform_slots': {'Twitch': False, 'Vomiting': False, 'Fever': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True,
#    'Vomiting': True,
#    'Stomach ache': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Nausea': False},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True,
#    'Bloating': True,
#    'Stomach ache': False,
#    'Feel sick and vomit': False,
#    'Chills and fever': False},
#   'implicit_inform_slots': {'Mucus pus and blood in the stool': False},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Stomach ache': True},
#   'implicit_inform_slots': {'Fear of cold': False,
#    'Nausea': False,
#    'Diarrhea': True,
#    'Abdominal pain and diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Palpitations': True, 'Diarrhea': True},
#   'implicit_inform_slots': {'Fear of cold': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Defecate': True,
#    'Stomach ache': True,
#    'Thirst': False,
#    'Feel sick and vomit': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Vomiting': False, 'Diarrhea': True},
#   'disease_tag': 'Enteritis'},
#  {'explicit_inform_slots': {'Diarrhea': True, 'Decreased urine output': True},
#   'implicit_inform_slots': {'Fever': False, 'Vomiting': True},
# ...
#    'Stuffy nose': True,
#    'Blood in the tears': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Runny nose': True,
#    'Suppuration': False,
#    'Cough': False,
#    'Inspiratory tri-concave sign': False},
#   'implicit_inform_slots': {'Fever': False},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Runny nose': True,
#    'Stuffy nose': True,
#    'Cough': False,
#    'Blood in the tears': False},
#   'implicit_inform_slots': {'Fever': False},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Sneeze': True,
#    'Nose bleeding': True,
#    'Headache': False},
#   'implicit_inform_slots': {'Nasal congestion': False},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Runny nose': True,
#    'Cough': True,
#    'Cyanosis': False,
#    'Expectoration': False,
#    'Chest tightness and shortness of breath': False,
#    'Fever': False,
#    'Shortness of breath': False},
#   'implicit_inform_slots': {'Hoarse': False, 'Stuffy nose': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Runny nose': True},
#   'implicit_inform_slots': {'Cry': False, 'Sneeze': True, 'Itchy eyes': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Sneeze': True, 'Stuffy nose': True},
#   'implicit_inform_slots': {'Cough': True, 'Snore': True, 'Runny nose': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Runny nose': True},
#   'implicit_inform_slots': {'Blood in the tears': False,
#    'Fever': False,
#    'Swelling of both nasal mucosa': True,
#    'Stuffy nose': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Runny nose': True,
#    'Cough': False},
#   'implicit_inform_slots': {'Fever': False},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Stuffy nose': True},
#   'implicit_inform_slots': {'Diarrhea': False,
#    'Vomiting': False,
#    'Cough': True,
#    'Runny nose': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Runny nose': True,
#    'Burning sensation behind the breastbone': False,
#    'Shortness of breath': False},
#   'implicit_inform_slots': {'Hemoptysis': False,
#    'Pain behind the breastbone': False,
#    'Cough': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Runny nose': True, 'Sneeze': True},
#   'implicit_inform_slots': {'Shortness of breath': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Sneeze': True,
#    'Stuffy nose': True,
#    'Cough': False,
#    'Runny nose': False},
#   'implicit_inform_slots': {'Fever': False, 'Snore': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Headache': True,
#    'Runny nose': True,
#    'Cough': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Pharynx discomfort': False},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Cough': True},
#   'implicit_inform_slots': {'Palpitations': False,
#    'Fever': False,
#    'Runny nose': True,
#    'Nasal mucosal congestion': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Stuffy nose': True},
#   'implicit_inform_slots': {'Chest tightness': False,
#    'Cough': False,
#    'Sneeze': True,
#    'Runny nose': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True},
#   'implicit_inform_slots': {'Fever': False,
#    'Vomiting': False,
#    'Stuffy nose': True,
#    'Runny nose': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Inspiratory tri-concave sign': False},
#   'implicit_inform_slots': {'Fever': False,
#    'Suppuration': False,
#    'Cough': True,
#    'First degree swelling of bilateral tonsils': True,
#    'Runny nose': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Stuffy nose': True},
#   'implicit_inform_slots': {'Fever': False,
#    'Blood in the tears': False,
#    'Sneeze': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Sneeze': True},
#   'implicit_inform_slots': {'Fever': False, 'Pharynx discomfort': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Cough': True},
#   'implicit_inform_slots': {'Fever': False,
#    'Pharynx discomfort': False,
#    'Runny nose': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Stuffy nose': True,
#    'Runny nose': True,
#    'Nose bleeding': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Fear of cold': False},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True},
#   'implicit_inform_slots': {'Fever': False,
#    'Headache': False,
#    'Stuffy nose': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Cough': True},
#   'implicit_inform_slots': {'Pharynx discomfort': False,
#    'Fever': False,
#    'Sneeze': True,
#    'Runny nose': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Runny nose': True},
#   'implicit_inform_slots': {'Fever': False,
#    'Nasal congestion': False,
#    'Stuffy nose': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Stuffy nose': True, 'Snore': True},
#   'implicit_inform_slots': {'Pharynx discomfort': False},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Nasal congestion': True,
#    'Headache': False,
#    'Consciousness disorder': False},
#   'implicit_inform_slots': {'Sneeze': False,
#    'Runny nose': False,
#    'Stuffy nose': True,
#    'Nose bleeding': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Cough': True},
#   'implicit_inform_slots': {'Stuffy nose': True,
#    'Runny nose': True,
#    'Sneeze': True,
#    'Itchy eyes': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Stuffy nose': True,
#    'Difficulty breathing': False,
#    'Pain behind the breastbone': False},
#   'implicit_inform_slots': {'Night sweats': False,
#    'Hemoptysis': False,
#    'Runny nose': True},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Stuffy nose': True, 'Sneeze': True},
#   'implicit_inform_slots': {'Headache': False},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Stuffy nose': True,
#    'Snore': True,
#    'Dizzy': False,
#    'Fever': False,
#    'Expectoration': False},
#   'implicit_inform_slots': {'Cough': False},
#   'disease_tag': 'Rhinitis'},
#  {'explicit_inform_slots': {'Mild thyroid enlargement': True, 'Fever': False},
#   'implicit_inform_slots': {'Stuffy nose': False,
#    'Cough': False,
#    'Pain in front of neck': True,
#    'Fatigue': True,
#    'Loss of appetite': True,
#    'Palpitations': True,
#    'Pharynx discomfort': True,
#    'Sweating': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Sweating': True,
#    'Mild thyroid enlargement': True},
#   'implicit_inform_slots': {'Pain in front of neck': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Pain in front of neck': True,
#    'Mild thyroid enlargement': True},
#   'implicit_inform_slots': {'Fever': False},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Headache': True, 'Vomiting': False},
#   'implicit_inform_slots': {'Fever': False,
#    'Nausea': False,
#    'Pharynx discomfort': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Fatigue': True,
#    'Pain in front of neck': True,
#    'Stuffy nose': False},
#   'implicit_inform_slots': {'Cough': False,
#    'Pharynx discomfort': True,
#    'Fever': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Mild thyroid enlargement': True,
#    'Pharynx discomfort': True,
#    'Palpitations': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Sweating': False,
#    'Pain in front of neck': True,
#    'Loss of appetite': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Poor spirits': True},
#   'implicit_inform_slots': {'Headache': True, 'Pharynx discomfort': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Pain in front of neck': True,
#    'Mild thyroid enlargement': True,
#    'Fatigue': False,
#    'Stuffy nose': False,
#    'Fever': False},
#   'implicit_inform_slots': {'Cough': False,
#    'Loss of appetite': True,
#    'Palpitations': True,
#    'Sweating': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Chest tightness and shortness of breath': True,
#    'Palpitations': True},
#   'implicit_inform_slots': {'Fatigue': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Palpitations': True,
#    'Chest tightness and shortness of breath': True,
#    'Proptosis': False,
#    'Fatigue': False,
#    'Edema': False},
#   'implicit_inform_slots': {'Hoarse': False},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Fatigue': True},
#   'implicit_inform_slots': {'Dizzy': True,
#    'Sleep disorder': True,
#    'Constipation': True,
#    'Hard to swallow': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Thin': True,
#    'Anorexia': True,
#    'Afraid of cold': False,
#    'Edema': False,
#    'Afraid of heat': False,
#    'Palpitations': False,
#    'Proptosis': False},
#   'implicit_inform_slots': {'Chest tightness': False},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Fatigue': True},
#   'implicit_inform_slots': {'Edema': False, 'Afraid of cold': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Pain in front of neck': True,
#    'Pharynx discomfort': True,
#    'Fatigue': False,
#    'Cough': False,
#    'Fever': False,
#    'Palpitations': False,
#    'Sweating': False},
#   'implicit_inform_slots': {'Stuffy nose': False,
#    'Headache': True,
#    'Loss of appetite': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Fever': True, 'Pain in front of neck': True},
#   'implicit_inform_slots': {'Fatigue': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Palpitations': True},
#   'implicit_inform_slots': {'Fever': False, 'Pain in front of neck': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True,
#    'Fever': True,
#    'Proptosis': False,
#    'Expectoration': False},
#   'implicit_inform_slots': {'Cough': False},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Sleep disorder': True},
#   'implicit_inform_slots': {'Proptosis': False,
#    'Fatigue': True,
#    'Afraid of cold': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Hoarse': True, 'Hiccough': True},
#   'implicit_inform_slots': {'Proptosis': False, 'Hard to swallow': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Palpitations': True},
#   'implicit_inform_slots': {'Syncope': False,
#    'Pain behind the breastbone': False,
#    'Dizziness': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Dizzy': True, 'Sleep disorder': True},
#   'implicit_inform_slots': {'Proptosis': False, 'Poor sleep': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Consciousness disorder': True,
#    'Dizziness': True,
#    'Shaking hands': False},
#   'implicit_inform_slots': {'Proptosis': False, 'Fatigue': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True},
#   'implicit_inform_slots': {'Hand tremor': False,
#    'Pain in front of neck': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Fever': True},
#   'implicit_inform_slots': {'Proptosis': False,
#    'Sweating': True,
#    'Palpitations': True,
#    'Fatigue': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Poor spirits': True},
#   'implicit_inform_slots': {'Proptosis': False,
#    'Stomach ache': False,
#    'Poor sleep': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Constipation': True, 'Fatigue': True},
#   'implicit_inform_slots': {'Sleep disorder': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Sweating': True},
#   'implicit_inform_slots': {'Palpitations': False,
#    'Afraid of heat': False,
#    'Thin': True,
#    'Fatigue': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Pain in front of neck': True, 'Fever': True},
#   'implicit_inform_slots': {'Mild thyroid enlargement': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Chest tightness and shortness of breath': True,
#    'Palpitations': False,
#    'Fear of cold': False},
#   'implicit_inform_slots': {'Shaking hands': False,
#    'Fever': False,
#    'Pharynx discomfort': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Headache': True},
#   'implicit_inform_slots': {'Fever': False, 'Mild thyroid enlargement': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Pain in front of neck': True},
#   'implicit_inform_slots': {'Fatigue': False,
#    'Fever': False,
#    'Mild thyroid enlargement': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Palpitations': True,
#    'Anorexia': True,
#    'Proptosis': False},
#   'implicit_inform_slots': {'Sleep disorder': False,
#    'Fatigue': True,
#    'Afraid of cold': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Edema': True, 'Shaking hands': True},
#   'implicit_inform_slots': {'Palpitations': True, 'Fatigue': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Palpitations': True},
#   'implicit_inform_slots': {'Proptosis': False, 'Thin': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Acid reflux': True},
#   'implicit_inform_slots': {'Chest tightness': True, 'Hoarse': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Mild thyroid enlargement': True, 'Cough': False},
#   'implicit_inform_slots': {'Fever': False,
#    'Stuffy nose': False,
#    'Pain in front of neck': True,
#    'Loss of appetite': True,
#    'Sweating': True,
#    'Palpitations': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Fatigue': True},
#   'implicit_inform_slots': {'Anorexia': False, 'Afraid of cold': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Pain in front of neck': True},
#   'implicit_inform_slots': {'Fever': False,
#    'Proptosis': False,
#    'Palpitations': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Sleep disorder': True, 'Fatigue': True},
#   'implicit_inform_slots': {'Palpitations': False},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Sleep disorder': True},
#   'implicit_inform_slots': {'Hand tremor': False,
#    'Poor spirits': True,
#    'Fatigue': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Pain in front of neck': True,
#    'Stuffy nose': False},
#   'implicit_inform_slots': {'Fever': False,
#    'Cough': False,
#    'Mild thyroid enlargement': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Pain in front of neck': True},
#   'implicit_inform_slots': {'Palpitations': False,
#    'Cough': False,
#    'Fever': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Stuffy nose': True,
#    'Cough': True,
#    'Fatigue': False},
#   'implicit_inform_slots': {'Fever': False,
#    'Mild thyroid enlargement': True,
#    'Pain in front of neck': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Chest tightness': True, 'Rash': True},
#   'implicit_inform_slots': {'Proptosis': False},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Pharynx discomfort': True, 'Fever': False},
#   'implicit_inform_slots': {'Palpitations': False,
#    'Cough': False,
#    'Fatigue': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Mild thyroid enlargement': True},
#   'implicit_inform_slots': {'Stuffy nose': False,
#    'Cough': True,
#    'Pain in front of neck': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Fatigue': True},
#   'implicit_inform_slots': {'Dizzy': True,
#    'Eye swelling': True,
#    'Palpitations': True,
#    'Cry': True,
#    'Sweating': True},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Shaking hands': True, 'Palpitations': True},
#   'implicit_inform_slots': {'Fever': False},
#   'disease_tag': 'Thyroiditis'},
#  {'explicit_inform_slots': {'Headache': True,
#    'Pharynx discomfort': True,
#    'Chest tightness': False,
#    'Hard to swallow': False,
#    'Fever': False,
#    'Expectoration': False},
#   'implicit_inform_slots': {'Acid reflux': False},
#   'disease_tag': 'Thyroiditis'},
#  ...]

# %%
with open('test.pk','rb') as f:
    test = pickle.load(f)
